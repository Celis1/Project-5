# %%
import pandas as pd
import requests

# %%
#trial 1
url = 'https://stream.twitter.com/1.1/statuses/sample.json'
header = ('auth', 'WZqvJyR9awl4vIyA5bkmOHEev')
requests.get(url, auth=header)

# %%
#trial 2
client_key = #'put your auth here'
client_secret = #'put your auth here'

import base64

key_secret = '{}:{}'.format(client_key, client_secret).encode('ascii')
b64_encoded_key = base64.b64encode(key_secret)
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://stream.twitter.com/1.1/statuses/sample.json'
auth_url = '{}oauth2/token'.format(base_url)

auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

auth_data = {
    'grant_type': 'client_credentials'
}

requests.post(auth_url, headers=auth_headers, data=auth_data)
# Out:
# <Response [401]>

# %%
auth_resp
# Out:
# <Response [401]>

# %%
#trial 3
url = 'https://stream.twitter.com/1.1/statuses/sample.json'
header = ('auth', #put your auth code here'')

requests.get(url)
# Out:
# <Response [401]>

# %%
url = 'https://twitter.com/?lang=en.json'
resp = requests.get(url)
resp.status_code
# Out:
# 200

# %%
resp.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" data-scribe-reduced-action-queue="true">\n  <head>\n    \n    \n    \n    \n    \n    \n    \n    <meta charset="utf-8">\n      <script  nonce="KqoTtSjgrzx5fa28Oyw3NQ==">\n        !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();\n      </script>\n    \n    \n  \n  <script id="bouncer_terminate_iframe" nonce="KqoTtSjgrzx5fa28Oyw3NQ==">\n    if (window.top != window) {\n  window.top.postMessage({\'bouncer\': true, \'event\': \'complete\'}, \'*\');\n}\n  </script>\n  <script id="resolve_inline_redirects" nonce="KqoTtSjgrzx5fa28Oyw3NQ==">\n    !function(){function n(){var n=window.location.href.match(/#(.)(.*)$/);return n&&"!"==n[1]&&n[2].replace(/^\\//,"")}function t(){var t=n();t&&window.location.replace("//"+window.location.host+"/"+t)}t(),window.addEventListener?window.addEventListener("h
# ...
